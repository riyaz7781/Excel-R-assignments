# %% [markdown]
# <a href="https://colab.research.google.com/github/riyaz7781/Excel-R-assignments/blob/main/Emotion_Mining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import the Necessary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import spacy
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Load the Dataset

# %%
data1=pd.read_csv("/content/Elon_musk.csv",encoding="latin1",error_bad_lines=False)
data1.head()
# Out:
#    Unnamed: 0                                               Text
# 0           1                             @kunalb11 Im an alien
# 1           2  @ID_AA_Carmack Ray tracing on Cyberpunk with H...
# 2           3                @joerogan @Spotify Great interview!
# 3           4                    @gtera27 Doge is underestimated
# 4           5  @teslacn Congratulations Tesla China for amazi...

# %% [markdown]
# Dropping the Numerical Column

# %%
data2=data1["Text"]
data2
# Out:
# 0                                  @kunalb11 Im an alien
# 1       @ID_AA_Carmack Ray tracing on Cyberpunk with H...
# 2                     @joerogan @Spotify Great interview!
# 3                         @gtera27 Doge is underestimated
# 4       @teslacn Congratulations Tesla China for amazi...
#                               ...
# 1994    @flcnhvy True, it sounds so surreal, but the n...
# 1995    @PPathole Make sure to read ur terms &amp; con...
# 1996                  @TeslaGong @PPathole Samwise Gamgee
# 1997    @PPathole Altho Dumb and Dumber is <U+0001F525...
# 1998                            Progress update August 28
# Name: Text, Length: 1999, dtype: object

# %%
data2 = [x.strip() for x in data2] # remove both the leading and the trailing characters
data2 = [x for x in data2 if x] # removes empty strings, because they are considered in Python as False
data2[0:10]
# Out:
# ['@kunalb11 I\x92m an alien',
#  '@ID_AA_Carmack Ray tracing on Cyberpunk with HDR is next-level. Have you tried it?',
#  '@joerogan @Spotify Great interview!',
#  '@gtera27 Doge is underestimated',
#  '@teslacn Congratulations Tesla China for amazing execution last year. Now on to the next for even more!!',
#  'Happy New Year of the Ox! https://t.co/9WFKMYu2oj',
#  'Frodo was the underdoge,\nAll thought he would fail,\nHimself most of all. https://t.co/zGxJFDzzrM',
#  '@OwenSparks_ @flcnhvy @anonyx10 Haha thanks :)',
#  '@flcnhvy @anonyx10 Indeed! Tweets definitely do not represent real-world time allocation.',
#  'The most entertaining outcome is the most likely']

# %%
nlp = spacy.load('en_core_web_sm')

# %%
one_block = data2[1]
doc_block = nlp(one_block)
spacy.displacy.render(doc_block, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">@ID_AA_Carmack
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ray
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  tracing on Cyberpunk with
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     HDR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is next-level. Have you tried it?</div></span>

# %% [markdown]
# Tokenisation

# %%
for token in doc_block[:]:
    print(token, token.pos_)
# Out:
# @ID_AA_Carmack ADV
# Ray PROPN
# tracing VERB
# on ADP
# Cyberpunk PROPN
# with ADP
# HDR PROPN
# is AUX
# next ADJ
# - PUNCT
# level NOUN
# . PUNCT
# Have AUX
# you PRON
# tried VERB
# it PRON
# ? PUNCT

# %%
nouns_verbs = [token.text for token in doc_block if token.pos_ in ('NOUN', 'VERB')]

#print(nouns_verbs[5:25])
nouns_verbs
# Out:
# ['tracing', 'level', 'tried']

# %% [markdown]
# Feature Extraction

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()
X = cv.fit_transform(nouns_verbs)
X
# Out:
# <3x3 sparse matrix of type '<class 'numpy.int64'>'
# 	with 3 stored elements in Compressed Sparse Row format>

# %%
temp_df = pd.DataFrame(X.toarray(), columns = cv.get_feature_names_out())
temp_df
# Out:
#    level  tracing  tried
# 0      0        1      0
# 1      1        0      0
# 2      0        0      1

# %%
sum_words = X.sum(axis=0)
wf_df = pd.DataFrame({'word' : cv.get_feature_names_out(),
                      'count' : np.array(sum_words).flatten()})
wf_df
# Out:
#       word  count
# 0    level      1
# 1  tracing      1
# 2    tried      1

# %%
wf_df[0:15].plot.bar(x='word', figsize=(6,3), title='Top verbs and nouns')
# Out:
# <Axes: title={'center': 'Top verbs and nouns'}, xlabel='word'>

# %% [markdown]
# Affin Dataset

# %%
affin1=pd.read_csv("/content/Afinn.csv",encoding="latin1")
affin1.head()
# Out:
#         word  value
# 0    abandon     -2
# 1  abandoned     -2
# 2   abandons     -2
# 3   abducted     -2
# 4  abduction     -2

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# Tokenisation

# %%
from nltk import tokenize
sentences = tokenize.sent_tokenize(" ".join(data2))
sentences
# Out:
# ['@kunalb11 I\x92m an alien @ID_AA_Carmack Ray tracing on Cyberpunk with HDR is next-level.',
#  'Have you tried it?',
#  '@joerogan @Spotify Great interview!',
#  '@gtera27 Doge is underestimated @teslacn Congratulations Tesla China for amazing execution last year.',
#  'Now on to the next for even more!!',
#  'Happy New Year of the Ox!',
#  'https://t.co/9WFKMYu2oj Frodo was the underdoge,\nAll thought he would fail,\nHimself most of all.',
#  'https://t.co/zGxJFDzzrM @OwenSparks_ @flcnhvy @anonyx10 Haha thanks :) @flcnhvy @anonyx10 Indeed!',
#  'Tweets definitely do not represent real-world time allocation.',
# ...

# %%
sent_df = pd.DataFrame(sentences, columns=['sentence'])
sent_df
# Out:
#                                               sentence
# 0    @kunalb11 Im an alien @ID_AA_Carmack Ray trac...
# 1                                   Have you tried it?
# 2                  @joerogan @Spotify Great interview!
# 3    @gtera27 Doge is underestimated @teslacn Congr...
# 4                   Now on to the next for even more!!
# ..                                                 ...
# 922  @kenyanwalstreet Not actually a payout, just a...
# 923  It may never pay out, as the stock cant b
#  ht...
# 924                                    Details Aug 28.
# 925  AI symbiosis while u wait @vistacruiser7 @flcn...
# 926  @TeslaGong @PPathole Samwise Gamgee @PPathole ...
#
# [927 rows x 1 columns]

# %% [markdown]
# Counting the Values

# %%
affinity_scores = affin1.set_index('word')['value'].to_dict()
affinity_scores
# Out:
# {'abandon': -2,
#  'abandoned': -2,
#  'abandons': -2,
#  'abducted': -2,
#  'abduction': -2,
#  'abductions': -2,
#  'abhor': -3,
#  'abhorred': -3,
#  'abhorrent': -3,
#  'abhors': -3,
#  'abilities': 2,
#  'ability': 2,
#  'aboard': 1,
#  'absentee': -1,
#  'absentees': -1,
#  'absolve': 2,
#  'absolved': 2,
#  'absolves': 2,
#  'absolving': 2,
#  'absorbed': 1,
#  'abuse': -3,
#  'abused': -3,
#  'abuses': -3,
#  'abusive': -3,
#  'accept': 1,
#  'accepted': 1,
#  'accepting': 1,
#  'accepts': 1,
#  'accident': -2,
#  'accidental': -2,
#  'accidentally': -2,
#  'accidents': -2,
#  'accomplish': 2,
#  'accomplished': 2,
#  'accomplishes': 2,
#  'accusation': -2,
#  'accusations': -2,
#  'accuse': -2,
#  'accused': -2,
#  'accuses': -2,
#  'accusing': -2,
#  'ache': -2,
#  'achievable': 1,
#  'aching': -2,
#  'acquit': 2,
#  'acquits': 2,
#  'acquitted': 2,
#  'acquitting': 2,
#  'acrimonious': -3,
#  'active': 1,
#  'adequate': 1,
#  'admire': 3,
#  'admired': 3,
#  'admires': 3,
# ...

# %%
nlp = spacy.load('en_core_web_sm')

# %%
sentiment_lexicon = affinity_scores
def calculate_sentiment(text: str = None):
    sent_score = 0
    if text:
        sentence = nlp(text)
        #print(sentence)
        for word in sentence:
            sent_score += sentiment_lexicon.get(word.lemma_, 0) #return 0 if key not found
    return sent_score

# %% [markdown]
# Predicting the Value based on Sentiment

# %%
calculate_sentiment(text = 'Amazing, wonderful session')
# Out:
# 8

# %%
calculate_sentiment(text = 'worst product and worst service ever')
# Out:
# -6

# %%
sent_df['sentiment_value'] = sent_df['sentence'].apply(calculate_sentiment)
sent_df
# Out:
#                                               sentence  sentiment_value
# 0    @kunalb11 Im an alien @ID_AA_Carmack Ray trac...                0
# 1                                   Have you tried it?                0
# 2                  @joerogan @Spotify Great interview!                3
# 3    @gtera27 Doge is underestimated @teslacn Congr...                3
# 4                   Now on to the next for even more!!                0
# ..                                                 ...              ...
# 922  @kenyanwalstreet Not actually a payout, just a...                0
# 923  It may never pay out, as the stock cant b
#  ht...               -4
# 924                                    Details Aug 28.                0
# 925  AI symbiosis while u wait @vistacruiser7 @flcn...               -2
# 926  @TeslaGong @PPathole Samwise Gamgee @PPathole ...                0
#
# [927 rows x 2 columns]

# %%
sent_df['word_count'] = sent_df['sentence'].str.split().apply(len)
sent_df
# Out:
#                                               sentence  sentiment_value  \
# 0    @kunalb11 Im an alien @ID_AA_Carmack Ray trac...                0
# 1                                   Have you tried it?                0
# 2                  @joerogan @Spotify Great interview!                3
# 3    @gtera27 Doge is underestimated @teslacn Congr...                3
# 4                   Now on to the next for even more!!                0
# ..                                                 ...              ...
# 922  @kenyanwalstreet Not actually a payout, just a...                0
# 923  It may never pay out, as the stock cant b
#  ht...               -4
# 924                                    Details Aug 28.                0
# 925  AI symbiosis while u wait @vistacruiser7 @flcn...               -2
# 926  @TeslaGong @PPathole Samwise Gamgee @PPathole ...                0
#
#      word_count
# 0            13
# 1             4
# 2             4
# 3            13
# ...

# %% [markdown]
# Scatterplot

# %%
sent_df.plot.scatter(x='word_count',
                     y='sentiment_value',
                     figsize=(6,4),
                     title='Sentence sentiment value to sentence word count')
# Out:
# <Axes: title={'center': 'Sentence sentiment value to sentence word count'}, xlabel='word_count', ylabel='sentiment_value'>
